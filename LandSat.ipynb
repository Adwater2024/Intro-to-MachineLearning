# %% [markdown]
# # Land Cover Classification Framework
#
# The workflow will cover how to retrieve LandSat Imagery to begin development of a landcover classifier. We will use the landcover classifier to examine changes over time.
#
# ## Case Application: Great Salt Lake
#
# The Great Salt Lake (GSL) fluctuates both from natural seasonality, year-to-year climate anomolies, and anthropogentic water use (e.g., diversions, growth, development). In today's example, we will retrieve LandSat imagery and develop a land cover classifier to examine the changes in area of the GSL over time.

# %%
from utils import getLandSat, plotting
import ee
import rasterio
import matplotlib.pyplot as plt
from IPython.display import Image, display
# Out:
# /home/civil/miniforge3/envs/hyriver/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# Earth Engine initialized successfully.

# %% [markdown]
# ### LandSat Data Retrievel
#
# Use the data retrievel functions to collect LandSat Imagery of the GSL

# %%
# Define the bounding box for the region of interest (ROI), we can get these coordinates from Google Earth or any GIS software. The coordinates are in the format [xmin, ymin, xmax, ymax].
xmin = -113.2
xmax = -111.95
ymin = 40.5
ymax = 41.85

# # Get the ROI as a GeoJSON object
roi = getLandSat.get_bbox([xmin, ymin, xmax, ymax])

#call the getLandSat function to download the data for the specified ROI and time range
getLandSat.export_monthly_range_parallel( #This function parallelizes the download of Landsat data for a specified region of interest (ROI) and time range, allowing for faster data retrieval.
    roi=roi, #roi: The region of interest defined as a GeoJSON object, specifying the area for which the Landsat data will be downloaded.
    output_dir="data/LandSat/GSL", #output_dir: The directory where the downloaded Landsat data will be saved. In this case, it is set to "data/LandSat/GSL".
    start_year=1985, #start_year: The starting year of the time range for which the Landsat data will be downloaded. In this case, it is set to 1985.
    end_year=2025, #end_year: The ending year of the time range for which the Landsat data will be downloaded. In this case, it is set to 2025.
    max_workers=3, #max_workers: The maximum number of worker threads to use for parallel processing. In this case, it is set to 3, which means that up to 3 threads will be used to download the data concurrently.
    months_before=2, #months_before: The number of months before the specified start year to include in the download. In this case, it is set to 2, which means that data from 2 months before the start year (1985) will also be included in the download.
    months_after=2, #months_after: The number of months after the specified end year to include in the download. In this case, it is set to 2, which means that data from 2 months after the end year (2025) will also be included in the download.
    reducer="median" #reducer: The method used to aggregate the Landsat data when multiple images are available for the same time period. In this case, it is set to "median", which means that the median value of the available images will be used for each pixel in the output data.
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Prepared 492 monthly jobs
# Generating URL ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/ef27978442fe6224374353ebabab7531-e19debcc4eecac527cadeec6ecc340f3:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/8ac8e5dd59a2a8d25231aa93ea360f4d-029f97e6251ec805d0c62218194ff960:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/81603fe4e40c43f9a7c35e217afb4e73-bbe91e0070faa3902aeebd4451c051f9:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_03.tif
# Saved to data/LandSat/GSL/GSL_1985_03.tif
# Finished: data/LandSat/GSL/GSL_1985_03.tif
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_02.tif
# Saved to data/LandSat/GSL/GSL_1985_02.tif
# Finished: data/LandSat/GSL/GSL_1985_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/5d28f03245b81340af1f3a22d81ce7ea-83d831ae2e86cb93772ee8f2bdb1cd6f:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/276394ee0b1f984bf42ff59a0e98bb5d-8acfa314d34ded8c4d18d36236e9dee1:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_01.tif
# Saved to data/LandSat/GSL/GSL_1985_01.tif
# Finished: data/LandSat/GSL/GSL_1985_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/055eb2db23da8bea2cf4c59a64fa44a5-44136006643a5c7b16243653bbeacfd7:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_04.tif
# Saved to data/LandSat/GSL/GSL_1985_04.tif
# Finished: data/LandSat/GSL/GSL_1985_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/c623f313cee69a58168755caddd84753-b2e69aeca7e4acdd02c7fa50f82398a1:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_06.tif
# Saved to data/LandSat/GSL/GSL_1985_06.tif
# Finished: data/LandSat/GSL/GSL_1985_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/0be2c76626b8143aa0ca491e2165c667-1f380aeaf7fa8f2ce517c1762ba3a937:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_05.tif
# Saved to data/LandSat/GSL/GSL_1985_05.tif
# Finished: data/LandSat/GSL/GSL_1985_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/3aadc850a5257fa9c1b012bff85b4ad0-f04ef3513b9feef5cdfcd1d1d00357bc:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_07.tif
# Saved to data/LandSat/GSL/GSL_1985_07.tif
# Finished: data/LandSat/GSL/GSL_1985_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/2a3838acc20aa72acaaacd0f3ca38038-3c453316468fc428ba7e98c568dbfce7:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_09.tif
# Saved to data/LandSat/GSL/GSL_1985_09.tif
# Finished: data/LandSat/GSL/GSL_1985_09.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_08.tif
# Saved to data/LandSat/GSL/GSL_1985_08.tif
# Finished: data/LandSat/GSL/GSL_1985_08.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/4d5126fbea70615369fef0fcfc56b564-60ff499f5fd67c290b541b4d2cad0118:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/d0c1d43901d1bb680bf4ec985d23e610-1a6c2c74d961c1f18738a55e778f52bf:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_10.tif
# Saved to data/LandSat/GSL/GSL_1985_10.tif
# Finished: data/LandSat/GSL/GSL_1985_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/f54154dc869a9e7611d592b4cd580386-223584e7929a03271c71455c9cb63add:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_12.tif
# Saved to data/LandSat/GSL/GSL_1985_12.tif
# Finished: data/LandSat/GSL/GSL_1985_12.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1985_11.tif
# Saved to data/LandSat/GSL/GSL_1985_11.tif
# Finished: data/LandSat/GSL/GSL_1985_11.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/90b92b2291246861ecf2b197a623a210-51c51c2db2a6cfcb0f6b96f0f8b4d06d:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/e8e88afd6b31ff3455cda53a57879c17-4b82cadce0fe4acb8fc5773e57183c99:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_01.tif
# Saved to data/LandSat/GSL/GSL_1986_01.tif
# Finished: data/LandSat/GSL/GSL_1986_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/251c68e70403ef37146ab9d21e4e4737-df60ffe128b4b402bfdba2c4c1cf3a5d:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_02.tif
# Saved to data/LandSat/GSL/GSL_1986_02.tif
# Finished: data/LandSat/GSL/GSL_1986_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/0d94c3f8398d158d237605f4f804900f-b2f38f77ee86e453ab338de4939da837:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_03.tif
# Saved to data/LandSat/GSL/GSL_1986_03.tif
# Finished: data/LandSat/GSL/GSL_1986_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/31d5666e8657421cd4855606075adb87-70408c7d6f0c199269c050c73f35af7b:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_04.tif
# Saved to data/LandSat/GSL/GSL_1986_04.tif
# Finished: data/LandSat/GSL/GSL_1986_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/40598051e7b80146e0f97647bc1743e0-00c6d202db35786a1fdbf6ec5448aa92:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_05.tif
# Saved to data/LandSat/GSL/GSL_1986_05.tif
# Finished: data/LandSat/GSL/GSL_1986_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/b16d46ee7e52e80b96022d7a944acf20-f7c2f423df60c1170e66bef4600ccf7a:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_06.tif
# Saved to data/LandSat/GSL/GSL_1986_06.tif
# Finished: data/LandSat/GSL/GSL_1986_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/7e9b726d37a62537116de1dfaf38d3de-db3d44c23cb51753d278ebdc35e4dae6:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_07.tif
# Saved to data/LandSat/GSL/GSL_1986_07.tif
# Finished: data/LandSat/GSL/GSL_1986_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/7d9ffce35fa0a6f3c3fac6b25ddacb06-76431f4a3850ba53a5278637c8d868c3:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_08.tif
# Saved to data/LandSat/GSL/GSL_1986_08.tif
# Finished: data/LandSat/GSL/GSL_1986_08.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_09.tif
# Saved to data/LandSat/GSL/GSL_1986_09.tif
# Finished: data/LandSat/GSL/GSL_1986_09.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/2853e9a6d8a53c3106251ba6cdcae067-65ec6536eaffedc7c590d94127094e15:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/3b16862cd6217576c8b420330aed2d82-011f75dfc2abeb9acd33b9d15d4c65e8:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_10.tif
# Saved to data/LandSat/GSL/GSL_1986_10.tif
# Finished: data/LandSat/GSL/GSL_1986_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/6615d513fd2069b7c24bd3b40a8accfa-bcf65c6564d602621b8cb248d171fddd:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_11.tif
# Saved to data/LandSat/GSL/GSL_1986_11.tif
# Finished: data/LandSat/GSL/GSL_1986_11.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1986_12.tif
# Saved to data/LandSat/GSL/GSL_1986_12.tif
# Finished: data/LandSat/GSL/GSL_1986_12.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/f0c223931f9037d3b155f5bfa6ed111d-2a9fd646381b1e4e9b91b2330abf44c3:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/51160944ff0879dc80df7403bb035c60-b3fc5093dd83382656e8026eca2f896d:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_01.tif
# Saved to data/LandSat/GSL/GSL_1987_01.tif
# Finished: data/LandSat/GSL/GSL_1987_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/da97f61966ae4a9514b608d2262a4ccb-5cf4d055f1f0c0b22cb868fd83819b52:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_02.tif
# Saved to data/LandSat/GSL/GSL_1987_02.tif
# Finished: data/LandSat/GSL/GSL_1987_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/dd734c7bf70827dc40df52dfe7e7c82a-e020557239ab6b7bbcefd7b45f4f78c1:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_03.tif
# Saved to data/LandSat/GSL/GSL_1987_03.tif
# Finished: data/LandSat/GSL/GSL_1987_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/07066d5bc2eced31e37f3a13d627c5f5-d19adc1d0789ea741cdd0506f495e6d2:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_04.tif
# Saved to data/LandSat/GSL/GSL_1987_04.tif
# Finished: data/LandSat/GSL/GSL_1987_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/f6221a3d6acd72316c75cd1a09f5581e-3afd72423d23ed32df36cc912821fa16:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_05.tif
# Saved to data/LandSat/GSL/GSL_1987_05.tif
# Finished: data/LandSat/GSL/GSL_1987_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/2d287bc2790436a223fd42850dcbfaad-59c2bb72d8945bd3651f212ed4b4d0a0:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987_06.tif
# Saved to data/LandSat/GSL/GSL_1987_06.tif
# Finished: data/LandSat/GSL/GSL_1987_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/f6e9f1c74e4625fc3a2120340cabf1fc-6782ba90f5853c1fe15078d3fa7d251d:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1987
09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/594b622dfdb947f1a970bc71f3c2cdf0-6a8d8aeeb5be48f0ca70dcf5ecfb2f02:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1988_11.tif
# Saved to data/LandSat/GSL/GSL_1988_11.tif
# Finished: data/LandSat/GSL/GSL_1988_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/c8d21ccd8bbbb39ac96363042f8af851-4023a15d53ba6c0184e05c7dcc644331:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1988_10.tif
# Saved to data/LandSat/GSL/GSL_1988_10.tif
# Finished: data/LandSat/GSL/GSL_1988_10.tif
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1988_12.tif
# Saved to data/LandSat/GSL/GSL_1988_12.tif
# Finished: data/LandSat/GSL/GSL_1988_12.tif
# Generating URL ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/43884f3fa276025207baf1f2656d64db-0c601c7cba7b6b37b60aebfa91684030:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/c86689cc2affda58bd1dafe27f1c8af3-17c9615d0e0ea0e6c2d0569940c03a0e:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_01.tif
# Saved to data/LandSat/GSL/GSL_1989_01.tif
# Finished: data/LandSat/GSL/GSL_1989_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/c8d9da1b5dc14fab6374567aed4dde28-f02e3f78ec7b5d52f1029ae8eb92a976:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_02.tif
# Saved to data/LandSat/GSL/GSL_1989_02.tif
# Finished: data/LandSat/GSL/GSL_1989_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/0a8c486c1f54bd8f6312564371d1b9db-fef77affd71482ad97e975191de1f30c:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_04.tif
# Saved to data/LandSat/GSL/GSL_1989_04.tif
# Finished: data/LandSat/GSL/GSL_1989_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/c5df72231245530f8b5b06cf16eb381a-710c517202040d70002579e3e55e1d8b:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_03.tif
# Saved to data/LandSat/GSL/GSL_1989_03.tif
# Finished: data/LandSat/GSL/GSL_1989_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/f277a9878ee2e8379850a428e6fdd3b0-8556d460e8dc6ac80548df1904d60269:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_06.tif
# Saved to data/LandSat/GSL/GSL_1989_06.tif
# Finished: data/LandSat/GSL/GSL_1989_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/2a2ec0f8f7b4b46f6e3627806f964fd5-5aa03cb8fa5aa327d6c1b2d28fadfb77:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_07.tif
# Saved to data/LandSat/GSL/GSL_1989_07.tif
# Finished: data/LandSat/GSL/GSL_1989_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/aab626bb04b5a83776a5f290d4604d0d-a0dfed1b718c1b39dad40932ec3d5d53:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_05.tif
# Saved to data/LandSat/GSL/GSL_1989_05.tif
# Finished: data/LandSat/GSL/GSL_1989_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/1d8fefa68059922b0543eaba7d151a0e-2c1f1869403cb74f99ecb38c78912fb0:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_08.tif
# Saved to data/LandSat/GSL/GSL_1989_08.tif
# Finished: data/LandSat/GSL/GSL_1989_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/3906c412629f7052f23a6ecb2529aac7-09ead28e00d2846f921ab3d5b9e0d9dd:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_10.tif
# Saved to data/LandSat/GSL/GSL_1989_10.tif
# Finished: data/LandSat/GSL/GSL_1989_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/1d665121b56b0c0cfca83f0ad54dd860-3e39c56f5fe08978ada65aff5597870f:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_11.tif
# Saved to data/LandSat/GSL/GSL_1989_11.tif
# Finished: data/LandSat/GSL/GSL_1989_11.tif
# No images for 1989-11-01 to 1990-04-01
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/d5b1d07e9513ea3cc8e269528d809158-2c6508e38dc9be45913cfaf3e0dca122:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_09.tif
# Saved to data/LandSat/GSL/GSL_1989_09.tif
# Finished: data/LandSat/GSL/GSL_1989_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/7c8fdb8d1056f8d91e3d94b4ee170049-3c42a441a8eefd2fb1e82e39091ec42d:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_02.tif
# Saved to data/LandSat/GSL/GSL_1990_02.tif
# Finished: data/LandSat/GSL/GSL_1990_02.tif
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1989_12.tif
# Saved to data/LandSat/GSL/GSL_1989_12.tif
# Finished: data/LandSat/GSL/GSL_1989_12.tif
# Generating URL ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/272df565a1de2c5e4fe98e3549bac4c2-45b6850024662ba14e8ddb5ec79035a5:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/5c5b48ac9678b096ba68810203339b19-279a4d2448069443f41d13b82008907c:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_03.tif
# Saved to data/LandSat/GSL/GSL_1990_03.tif
# Finished: data/LandSat/GSL/GSL_1990_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/cace9a7767e6a1db09ea5274c39d1468-bf676388466d1c9123d6af90a2668c5d:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_04.tif
# Saved to data/LandSat/GSL/GSL_1990_04.tif
# Finished: data/LandSat/GSL/GSL_1990_04.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_05.tif
# Saved to data/LandSat/GSL/GSL_1990_05.tif
# Finished: data/LandSat/GSL/GSL_1990_05.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/1cd17620d88bc3dce08a8bd55cced672-eb2b72feafc6e4ef8d5079c0cb44749e:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/24a88216b62ead00a66abd9cb31b1153-375ff023dd38e5d03628cbedadd8d5b9:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_06.tif
# Saved to data/LandSat/GSL/GSL_1990_06.tif
# Finished: data/LandSat/GSL/GSL_1990_06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/e3c16cb6cfcdcd213de5fd55c0178d5c-b652d27954969c4646ec0b8f9e987255:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_07.tif
# Saved to data/LandSat/GSL/GSL_1990_07.tif
# Finished: data/LandSat/GSL/GSL_1990_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/e5d25460aa1d90db6236ae6f7e11c33c-ebdd49fd4be27438bf0b0aadcbb98484:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_08.tif
# Saved to data/LandSat/GSL/GSL_1990_08.tif
# Finished: data/LandSat/GSL/GSL_1990_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/572b000a21ff883622fd30f1cd32a7e2-498e57247666b39479cf195520a36d2e:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_09.tif
# Saved to data/LandSat/GSL/GSL_1990_09.tif
# Finished: data/LandSat/GSL/GSL_1990_09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/5a89d7b14d1c71e803366d925b5bc4bf-8214fea60b20764c5e414faafc4286c9:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_12.tif
# Saved to data/LandSat/GSL/GSL_1990_12.tif
# Finished: data/LandSat/GSL/GSL_1990_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/02ba928031c9163199cfe90b0c1dcff1-d3dcc4438d7015ae4335349f331b072e:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_10.tif
# Saved to data/LandSat/GSL/GSL_1990_10.tif
# Finished: data/LandSat/GSL/GSL_1990_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/7aaee4daffc62dfbf3577c5df4e65b70-e99f6d4b27f7ab6bd77ad48c13ce9730:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1990_11.tif
# Saved to data/LandSat/GSL/GSL_1990_11.tif
# Finished: data/LandSat/GSL/GSL_1990_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/d82224f9a5434a343410a70f9e704881-1f9ce84a94896012ef6de0319cfaa24d:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_01.tif
# Saved to data/LandSat/GSL/GSL_1991_01.tif
# Finished: data/LandSat/GSL/GSL_1991_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/dc36c9ce249b2b04f9543201b2c8b850-c7a6e797fc703783bbaf5a83e23c7067:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1991_02.tif
# Saved to data/LandSat/GSL/GSL_1991_02.tif
# Finished: data/LandSat/GSL/GSL_1991_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails
11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/6b32b390cbddd2545a0976f965b32cd3-5783b029c35be3b7dc1692d10a823091:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1994_12.tif
# Saved to data/LandSat/GSL/GSL_1994_12.tif
# Finished: data/LandSat/GSL/GSL_1994_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/7a4dea5bfe39dd9c043c3a18726306bb-a4d53cf9cad1795a4dcf569b02d1e72d:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1994_10.tif
# Saved to data/LandSat/GSL/GSL_1994_10.tif
# Finished: data/LandSat/GSL/GSL_1994_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/b6cbcd9937a5e2e0386b0a99e82fdff2-fb06b0f0241f1e39c238d4682205ee74:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1995_02.tif
# Saved to data/LandSat/GSL/GSL_1995_02.tif
# Finished: data/LandSat/GSL/GSL_1995_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/cbbd5c84992c8fe11cec98aa9b159535-0a0afd781614bbc98e10228944cd151e:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1995_03.tif
# Saved to data/LandSat/GSL/GSL_1995_03.tif
# Finished: data/LandSat/GSL/GSL_1995_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/0cc2558785a728f09ff1d8efeeaa219e-f8a5c235446c293f4bf20e28fd62fe4d:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1995_01.tif
# Saved to data/LandSat/GSL/GSL_1995_01.tif
# Finished: data/LandSat/GSL/GSL_1995_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/2b0fb3ed215c1ab8578811b7ed91c718-07e29f1c04cedea591f7b43144c53bfe:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1995_04.tif
# Saved to data/LandSat/GSL/GSL_1995_04.tif
# Finished: data/LandSat/GSL/GSL_1995_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/f18b94adcd550a5e19749decb9c033a0-a12fa6ca95416a4f2dbb28022cc5fc6f:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_1995_05.tif
# ...
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/b7a9cac17d3ba5b4bf0e82f19d13d257-9dad6b073d052696a43ce80d8f2a7837:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_06.tif
# Saved to data/LandSat/GSL/GSL_2022_06.tif
# Finished: data/LandSat/GSL/GSL_2022_06.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_07.tif
# Saved to data/LandSat/GSL/GSL_2022_07.tif
# Finished: data/LandSat/GSL/GSL_2022_07.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_08.tif
# Saved to data/LandSat/GSL/GSL_2022_08.tif
# Finished: data/LandSat/GSL/GSL_2022_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/61bc0982d2da5f0fecd06664dd73fe38-e5befed922ac1352e1754a3c8f10bbfa:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/28b6a2bd41d87c620b97652b8040af25-2043657a4803d03f67d542e1022af7ca:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/878b74bdb588e13c3cd70f79831e9d94-7b98059f6d87ac6b2386ea319aaca345:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_11.tif
# Saved to data/LandSat/GSL/GSL_2022_11.tif
# Finished: data/LandSat/GSL/GSL_2022_11.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_10.tif
# Saved to data/LandSat/GSL/GSL_2022_10.tif
# Finished: data/LandSat/GSL/GSL_2022_10.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_09.tif
# Saved to data/LandSat/GSL/GSL_2022_09.tif
# Finished: data/LandSat/GSL/GSL_2022_09.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/bd3260367197ab366ebac3149fa87c89-e09e21ea54efa9e12d9bfc7b2048b9cf:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/17f572d29141162dabe9ccb88c76ba3c-6b726679f1e2b676291ba860429528db:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/b4595fa8f693815867e7c46efe7b2dd2-5ede22631b48630ae4d36dbc2a83dc57:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2022_12.tif
# Saved to data/LandSat/GSL/GSL_2022_12.tif
# Finished: data/LandSat/GSL/GSL_2022_12.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_01.tif
# Saved to data/LandSat/GSL/GSL_2023_01.tif
# Finished: data/LandSat/GSL/GSL_2023_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/df0520ec9137b9eb32c86398eb0291fe-bc2066532ce7086b2f48baa03f7df618:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_02.tif
# Saved to data/LandSat/GSL/GSL_2023_02.tif
# Finished: data/LandSat/GSL/GSL_2023_02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/94bbfe37db5908a323ad2d6f49e41346-fbe93a8d21bb096073797f27976fd9f1:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_03.tif
# Saved to data/LandSat/GSL/GSL_2023_03.tif
# Finished: data/LandSat/GSL/GSL_2023_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/e3369006bd05626f349996b070cfc12c-49186ba25be4241499fb0739f32df2c3:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_04.tif
# Saved to data/LandSat/GSL/GSL_2023_04.tif
# Finished: data/LandSat/GSL/GSL_2023_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/05e8f98380ab1341730c7f6db0e50831-cb7fa28ae1a1e1722fb9dceaf97ed8b1:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_05.tif
# Saved to data/LandSat/GSL/GSL_2023_05.tif
# Finished: data/LandSat/GSL/GSL_2023_05.tif
# Generating URL ...Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/f9e195572443e469663d08d21071c211-8a82f7579c291ff0568fd23ac2ff64bc:getPixels
# Please wait ...
#
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_06.tif
# Saved to data/LandSat/GSL/GSL_2023_06.tif
# Finished: data/LandSat/GSL/GSL_2023_06.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_07.tif
# Saved to data/LandSat/GSL/GSL_2023_07.tif
# Finished: data/LandSat/GSL/GSL_2023_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/08c3f08607382c725a744de16d1d682f-b6fb8b0b80c755bcd79c42c9bd5c0264:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/1c3d08befcabed12bd6b2e9c70e0f2e2-3fcce13efb655a957939de70ab9814f6:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/fb434fcff1d3764935ea13f91872dad1-33c4d3b9a7307daf411557edde5b618b:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_08.tif
# Saved to data/LandSat/GSL/GSL_2023_08.tif
# Finished: data/LandSat/GSL/GSL_2023_08.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_09.tif
# Saved to data/LandSat/GSL/GSL_2023_09.tif
# Finished: data/LandSat/GSL/GSL_2023_09.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_10.tif
# Saved to data/LandSat/GSL/GSL_2023_10.tif
# Finished: data/LandSat/GSL/GSL_2023_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/3d556971ceaa3979c96820ce4b72e14e-929cd66fdb433e6ae8d0e61e2097eb8a:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/e340e868e2cff117a1c3ac256392c81c-33f0d2d1e8d147d1b6b9d322f140bd67:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/5ca15a4133c5a97e7aee0d28fff16482-c1fee51357eddce38ff65d581aa66eb1:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_11.tif
# Saved to data/LandSat/GSL/GSL_2023_11.tif
# Finished: data/LandSat/GSL/GSL_2023_11.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2023_12.tif
# Saved to data/LandSat/GSL/GSL_2023_12.tif
# Finished: data/LandSat/GSL/GSL_2023_12.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_01.tif
# Saved to data/LandSat/GSL/GSL_2024_01.tif
# Finished: data/LandSat/GSL/GSL_2024_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/7e4db474e963a2e923071191864bfb5a-5dc6e423325e217d15d2f09d75b01e99:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/b94d2580f905daecdd53306f1cb17312-af2af12e355f678ae15d016902805f73:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/8921329501e055ef1e50b2faef1c2964-f49a0e9587329cbdf5d6047f1a6d6fbd:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_02.tif
# Saved to data/LandSat/GSL/GSL_2024_02.tif
# Finished: data/LandSat/GSL/GSL_2024_02.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_03.tif
# Saved to data/LandSat/GSL/GSL_2024_03.tif
# Finished: data/LandSat/GSL/GSL_2024_03.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_04.tif
# Saved to data/LandSat/GSL/GSL_2024_04.tif
# Finished: data/LandSat/GSL/GSL_2024_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/030585d120936d54e9f00d943cf3eef8-3c8940b1e5b3227c2659f097d5aec141:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/3c1f5afc4b3d1e8c7dc794c0c4d7f0f4-73b8779c21a0751e9cc5a58c593dbb0c:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/c45bfca3080aa39af18b2639c717cfb6-12fc9839bb43264dbc09dd2903caaaed:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_05.tif
# Saved to data/LandSat/GSL/GSL_2024_05.tif
# Finished: data/LandSat/GSL/GSL_2024_05.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_06.tif
# Saved to data/LandSat/GSL/GSL_2024_06.tif
# Finished: data/LandSat/GSL/GSL_2024_06.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_07.tif
# Saved to data/LandSat/GSL/GSL_2024_07.tif
# Finished: data/LandSat/GSL/GSL_2024_07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/57bcc670a6ed98194ca193ca5f2a8847-294df3ddde6a134bd43482ab893c27b4:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/461036aec74b8ec2dec1caec93e637aa-57429a9b508282f5b1c6c7db419ec1db:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/56e06ce324a1d443c7eb9accb03e6288-d7baf2586808bfab1f4b06f4fffdc14b:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_09.tif
# Saved to data/LandSat/GSL/GSL_2024_09.tif
# Finished: data/LandSat/GSL/GSL_2024_09.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_08.tif
# Saved to data/LandSat/GSL/GSL_2024_08.tif
# Finished: data/LandSat/GSL/GSL_2024_08.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/1055bb635cd69b9dcff99e2fe08377c8-d67487313e78ca1df3b33ba973a4ac63:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_10.tif
# Saved to data/LandSat/GSL/GSL_2024_10.tif
# Finished: data/LandSat/GSL/GSL_2024_10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/b13d5dba3e5aae907e4d3a05dd82189f-79b2105e234bf796c8d6a0cb8e27d5a1:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/aa3499ffccf5380dd576233d36a2088b-4d36b0876b7618b2d8e99726f88469d7:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_11.tif
# Saved to data/LandSat/GSL/GSL_2024_11.tif
# Finished: data/LandSat/GSL/GSL_2024_11.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2024_12.tif
# Saved to data/LandSat/GSL/GSL_2024_12.tif
# Finished: data/LandSat/GSL/GSL_2024_12.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_01.tif
# Saved to data/LandSat/GSL/GSL_2025_01.tif
# Finished: data/LandSat/GSL/GSL_2025_01.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/846670a04535beb1a680f21ac80d5c22-12242e73a6bde98bcc0d410640aa55dd:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/1293d22bc18c306cfd52eef0a083c7c4-9c01d71763264ba0a300f578fc32757c:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_02.tif
# Saved to data/LandSat/GSL/GSL_2025_02.tif
# Finished: data/LandSat/GSL/GSL_2025_02.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/681bd72f756eade84e861f8416b45f8b-7dff77c7bb3ce0b74b12cbdad1e5b019:getPixels
# Please wait ...
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_04.tif
# Saved to data/LandSat/GSL/GSL_2025_04.tif
# Finished: data/LandSat/GSL/GSL_2025_04.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/0d1b08836dcac47e4146c8a4e91c25c9-2032190419ce4755f262a1c4ac6b2cc4:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_03.tif
# Saved to data/LandSat/GSL/GSL_2025_03.tif
# Finished: data/LandSat/GSL/GSL_2025_03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/2c040ae7f7ce7a918efa8d1527adb95c-0f19ee83234c62143a3d0f98f98eaf22:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_05.tif
# Saved to data/LandSat/GSL/GSL_2025_05.tif
# Finished: data/LandSat/GSL/GSL_2025_05.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/46554ab60bce54927d1c9c4ce288d3b7-9a527b953f799f2e5e6629a22896d47b:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/a7172b27d08203e96285c3c9b7796f2f-10365bfd1e8eeed586d8d93070cbc35f:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_06.tif
# Saved to data/LandSat/GSL/GSL_2025_06.tif
# Finished: data/LandSat/GSL/GSL_2025_06.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_08.tif
# Saved to data/LandSat/GSL/GSL_2025_08.tif
# Finished: data/LandSat/GSL/GSL_2025_08.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_07.tif
# Saved to data/LandSat/GSL/GSL_2025_07.tif
# Finished: data/LandSat/GSL/GSL_2025_07.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/cbca47d0c94fcff613f701f79234c9be-51fa4ba349dcff6f7bcbf78381c01f4b:getPixels
# Please wait ...
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/8209ce1b56f5feaf34d8f98a0c5a7528-f200121b52a67a6debeb3ed837696784:getPixels
# Please wait ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/da5c6542d9c25fb754271e594846017e-4866b9e0e7f8cecd1dc42fa4bb8298a9:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_09.tif
# Saved to data/LandSat/GSL/GSL_2025_09.tif
# Finished: data/LandSat/GSL/GSL_2025_09.tif
# Generating URL ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_11.tif
# Saved to data/LandSat/GSL/GSL_2025_11.tif
# Finished: data/LandSat/GSL/GSL_2025_11.tif
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_10.tif
# Saved to data/LandSat/GSL/GSL_2025_10.tif
# Finished: data/LandSat/GSL/GSL_2025_10.tif
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-acossey11/thumbnails/1d7dce14e71cb29940eef277cbc8ac43-0e0ed3c08b91871c8f717543124ef924:getPixels
# Please wait ...
# Data downloaded to /home/civil/Intro-to-MachineLearning/data/LandSat/GSL/GSL_2025_12.tif
# Saved to data/LandSat/GSL/GSL_2025_12.tif
# Finished: data/LandSat/GSL/GSL_2025_12.tif
# All monthly exports completed.

# %% [markdown]
# ## Plot some images
#
# We want to plot some of the images to double check out work.
# * How does the image look?
# * Is the bounding box correct?
# * How is the color scaling?

# %%
Path = 'data/LandSat/GSL/' #The directory where the downloaded Landsat data is saved. In this case, it is set to "data/LandSat/GSL/".
date = '1986_01' #The specific date for which the Landsat image will be plotted. In this case, it is set to '1986_01', which likely corresponds to January 1986.

# This function call for plotting the Landsat image for the specified date using the data stored in the specified directory. The function reads the relevant Landsat data from the directory, processes it, and then generates a visual representation of the image for the given date.
plotting.plot_landsat_image(Path, date)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Exploring changes over time
#
# A key element of the exercise is to quantitatively describe changes in GSL surface area over time. A first step is to qualitaively do this by making a time-series gif of the images and visually assess if we in fact do observed changes.

# %%
plotting.make_gif_from_tifs(
    input_dir="data/LandSat/GSL",
    output_gif="data/LandSat/GSL/gsl_timelapse.gif",
    frame_duration=.8,
    max_width=400,
    font_size=40
)

display(Image(filename="data/LandSat/GSL/gsl_timelapse.gif"))

# %% [markdown]
# ### Lets trainsition to model development
#
# Now that we have the data, we can start developing it to train our ML model in [LC_Classifier](LC_Classifier.ipynb)
